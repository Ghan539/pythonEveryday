# %% [markdown]
# <a href="https://colab.research.google.com/github/Ghan539/pythonEveryday/blob/main/task1/session_1_tasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task : Session 1
# Solve these questions own your own and try to test yourself what you have learned in the session.
#
# Happy Learning!

# %% [markdown]
# ### Q1 :- Print the given strings as per stated format.
#
# **Given strings**:
# ```
# "Data" "Science" "Mentorship" "Program"
# "By" "CampusX"
# ```
# **Output**:
# ```
# Data-Science-Mentorship-Program-started-By-CampusX
# ```
#
# Concept- [Seperator and End]

# %%
print("Data","Science","Mentorship","Program"
"By","CampusX",sep="-")
# Out:
# Data-Science-Mentorship-ProgramBy-CampusX

# %% [markdown]
# ### Q2:- Write a program that will convert celsius value to fahrenheit.

# %%
c=int(input("Enter the celsius : "))

f=(9/5*c+32)
print("fahrenheit value :",f)
# Out:
# Enter the celsius : 30
# fahrenheit value : 86.0

# %% [markdown]
# ### Q3:- Take 2 numbers as input from the user.Write a program to swap the numbers without using any special python syntax.

# %%
a=int(input("Enter the a :"))
b=int(input("Enter the b :"))

print("before swap :",a,b)

temp=a
a=b
b=temp

print("after swap :",a,b)
# Out:
# Enter the a :45
# Enter the b :78
# before swap : 45 78
# after swap : 78 45

# %% [markdown]
# ### Q4:- Write a program to find the euclidean distance between two coordinates.Take both the coordinates from the user as input.

# %%
x1=int(input("Enter the x1 cordinate : "))
x2=int(input("Enter the x2 cordinate : "))
y1=int(input("Enter the y1 cordinate : "))
y2=int(input("Enter the y2 cordinate : "))

D=((x2-x1)*(x2-x1))+((y2-y1)*(y2-y1))

print("Distance :",D**0.5)
# Out:
# Enter the x1 cordinate : 56
# Enter the x2 cordinate : 87
# Enter the y1 cordinate : 96
# Enter the y2 cordinate : 34
# Distance : 69.31810730249349

# %% [markdown]
# ### Q5:- Write a program to find the simple interest when the value of principle,rate of interest and time period is provided by the user.

# %%
p=eval(input("Enter the priciple :"))
r=eval(input("Enter the rate :"))
t=eval(input("Enter the time :"))

si=(p*r*t)/100

print("interest",round(si,4))
# Out:
# Enter the priciple :10000
# Enter the rate :5
# Enter the time :0.84
# interest 420.0

# %% [markdown]
# ### Q6:- Write a program that will tell the number of dogs and chicken are there when the user will provide the value of total heads and legs.
#
# For example:
# Input:
# heads -> 4
# legs -> 12
# <br>
# Output:
# dogs -> 2
# chicken -> 2

# %%
h=int(input("Enter the heads:"))
l=int(input("enter the legs :"))



c=(4*h-l)//2
dog=h-c

print("No of dogs",dog)
print("No of chicken",c)
# Out:
# Enter the heads:23
# enter the legs :45
# No of dogs 0
# No of chicken 23

# %% [markdown]
# ### Q7:- Write a program to find the sum of squares of first n natural numbers where n will be provided by the user.

# %%
n=int(input("Enter the number n :"))
s=0
for i in range(1,n+1):
  s=s+(i**2)
print(s)
# Out:
# Enter the number n :10
# 385

# %% [markdown]
# ### Q8:- Given the first 2 terms of an Arithmetic Series.Find the Nth term of the series. Assume all inputs are provided by the user.

# %%
a1=int(input("Enter the 1st term :"))
d=int(input("Enter the common diff:"))
print("Enter the 2nd term ",a1+d)
n=int(input("Enter the nth term :"))

an=a1+(n-1)*d

print(n,"th term is :",an)
# Out:
# Enter the 1st term :12
# Enter the common diff:4
# Enter the 2nd term  16
# Enter the nth term :10
# 10 th term is : 48

# %% [markdown]
# ### Q9:- Given 2 fractions, find the sum of those 2 fractions.Take the numerator and denominator values of the fractions from the user.

# %%
num1=int(input("enter the (fact1) numerator :"))
deno1=int(input("enter the (fact1) denominator :"))

num2=int(input("enter the (fact2) numerator :"))
deno2=int(input("enter the (fact2) denominator :"))

n=((num1*deno2)+(num2*deno1))
d=deno1*deno2

print("sum",n,"/",d)
# Out:
# enter the (fact1) numerator :12
# enter the (fact1) denominator :43
# enter the (fact2) numerator :54
# enter the (fact2) denominator :6
# sum 2394 / 258

# %% [markdown]
# ### Q10:- Given the height, width and breadth of a milk tank, you have to find out how many glasses of milk can be obtained? Assume all the inputs are provided by the user.
#
#
#
# Input:<br>
# Dimensions of the milk tank<br>
# H = 20cm, L = 20cm, B = 20cm
# <br><br>
# Dimensions of the glass<br>
# h = 3cm, r = 1cm

# %%
print("dimension of milk tank")
L=int(input("Enter length :"))
B=int(input("Enter breadth:"))
H=int(input("Enter height :"))


print("dimension of glass")
h=int(input("Enter height :"))
r=int(input("Enter radius :"))

vol1=L*B*H
vol2=3.14*r*r*h


no=vol1//vol2

print("no of glasses :",int(no))55
# Out:
# dimension of milk tank
# Enter length :3535
# Enter breadth:65
# Enter height :465
# dimension of glass
# Enter height :6
# Enter radius :5
# no of glasses : 226847
